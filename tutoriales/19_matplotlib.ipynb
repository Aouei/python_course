# %% [markdown]
# # Matplotlib
#
# Matplotlib es una librería de Python montada bajo Numpy con la finalidad de generar gráficas. <br>
# Está basada en Matlab y que ese lenguaje, se suele usar mucho en Ciencia y en ingeniería.

# %% [markdown]
# ## Gráfico de líneas

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 4, -3, 8, 10]

# Crear el gráfico de líneas
plt.plot(x, y)

# Personalizar el gráfico
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Líneas')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Gráfico de disperción

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 4, -3, 8, 10]

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Personalizar el gráfico
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Dispersión')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Gráfico de barras

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = ['A', 'B', 'C', 'D']
y = [10, 15, 7, 12]

# Crear el gráfico de barras
plt.bar(x, y)

# Personalizar el gráfico
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.title('Gráfico de Barras')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Usando mapas de colores y leyendas de color

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear datos de ejemplo
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

# Crear el gráfico de contorno con colormap
plt.contourf(X, Y, Z, cmap='viridis')

# Agregar una barra de colores
plt.colorbar()

# Personalizar el gráfico
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de Contorno con Colormap')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Gráficos 3D

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Crear la figura y los ejes 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Crear la superficie 3D
ax.plot_surface(X, Y, Z, cmap='viridis')

# Personalizar el gráfico
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Gráfico 3D')

# Mostrar el gráfico
plt.show()
